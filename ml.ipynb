# %% [markdown]
# # Real Estate Analysis
# - ML, PyCaret, etc.

# %%
import pandas as pd

# %%
df = pd.read_csv('utah_sold_properties_2023.csv')
df.head()
# Out:
#    Unnamed: 0                                       property_url   mls  \
# 0           0  https://www.realtor.com/realestateandhomes-det...  ICUT
# 1           1  https://www.realtor.com/realestateandhomes-det...  SAUT
# 2           2  https://www.realtor.com/realestateandhomes-det...  SAUT
# 3           3  https://www.realtor.com/realestateandhomes-det...  SAUT
# 4           4  https://www.realtor.com/realestateandhomes-det...  SAUT
#
#     mls_id status                                               text  \
# 0   100473   SOLD  Enjoy gorgeous mountain views from this beauti...
# 1  1827010   SOLD  PROJECTED COMPLETION DATE OF January 2023. 5-P...
# 2  1820270   SOLD  Utah County's fastest-growing home builder! Ou...
# 3  1848218   SOLD  Come see this charming home now on the market!...
# 4  1849453   SOLD  BACK ON THE MARKET | BUYERS FINANCING FELL THR...
#
#            style              full_street_line                      street  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30018 entries, 0 to 30017
# Data columns (total 44 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        30018 non-null  int64
#  1   property_url      30018 non-null  object
#  2   mls               25667 non-null  object
#  3   mls_id            25667 non-null  object
#  4   status            30018 non-null  object
#  5   text              25157 non-null  object
#  6   style             29982 non-null  object
#  7   full_street_line  29861 non-null  object
#  8   street            29647 non-null  object
#  9   unit              8704 non-null   object
#  10  city              30006 non-null  object
#  11  state             30018 non-null  object
#  12  zip_code          30018 non-null  int64
#  13  beds              25967 non-null  float64
#  14  full_baths        25885 non-null  float64
#  15  half_baths        9827 non-null   float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0      zip_code          beds    full_baths   half_baths  \
# count  30018.000000  30018.000000  25967.000000  25885.000000  9827.000000
# mean   15008.500000  84295.589380      3.692918      2.194476     1.036227
# std     8665.594527    371.211553      1.461743      1.058865     0.201537
# min        0.000000  84001.000000      0.000000      1.000000     1.000000
# 25%     7504.250000  84045.000000      3.000000      2.000000     1.000000
# 50%    15008.500000  84106.000000      3.000000      2.000000     1.000000
# 75%    22512.750000  84653.000000      4.000000      3.000000     1.000000
# max    30017.000000  99999.000000     96.000000     48.000000     4.000000
#
#                 sqft    year_built  days_on_mls    list_price  sold_price  \
# count   26543.000000  26739.000000  6282.000000  2.566600e+04         0.0
# mean     2405.748672   1996.418602    97.835721  6.395078e+05         NaN
# ...

# %% [markdown]
# ### Filter for just columns that are useful for ML Algorithms

# %%
df_filtered = df.drop(columns=['Unnamed: 0', 'property_url', 'mls', 'mls_id', 'full_street_line', 'street', 'unit', 'text', 'list_date',
                               'agent', 'agent_email', 'agent_phones', 'broker', 'broker_phone', 'broker_phone', 'broker_website',
                               'primary_photo', 'alt_photos', 'status'])

# %% [markdown]
# - Keeping 'last_sold_date' to extract the month, could be useful

# %%
df_filtered.columns
# Out:
# Index(['style', 'city', 'state', 'zip_code', 'beds', 'full_baths',
#        'half_baths', 'sqft', 'year_built', 'days_on_mls', 'list_price',
#        'sold_price', 'last_sold_date', 'assessed_value', 'estimated_value',
#        'lot_sqft', 'price_per_sqft', 'latitude', 'longitude', 'neighborhoods',
#        'county', 'fips_code', 'stories', 'hoa_fee', 'parking_garage',
#        'nearby_schools'],
#       dtype='object')

# %%
# Convert 'last_sold_date' to datetime format
df_filtered['last_sold_date'] = pd.to_datetime(df_filtered['last_sold_date'])

# extract month from 'last_sold_date'
df_filtered['sold_month'] = df_filtered['last_sold_date'].dt.month

# %%
# verify results
df_filtered[['last_sold_date', 'sold_month']].head()
# Out:
#   last_sold_date  sold_month
# 0     2023-01-31           1
# 1     2023-01-31           1
# 2     2023-01-31           1
# 3     2023-01-31           1
# 4     2023-01-31           1

# %%
df_filtered = df_filtered.drop(columns=['last_sold_date'])

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30018 entries, 0 to 30017
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   style            29982 non-null  object
#  1   city             30006 non-null  object
#  2   state            30018 non-null  object
#  3   zip_code         30018 non-null  int64
#  4   beds             25967 non-null  float64
#  5   full_baths       25885 non-null  float64
#  6   half_baths       9827 non-null   float64
#  7   sqft             26543 non-null  float64
#  8   year_built       26739 non-null  float64
#  9   days_on_mls      6282 non-null   float64
#  10  list_price       25666 non-null  float64
#  11  sold_price       0 non-null      float64
#  12  assessed_value   22638 non-null  float64
#  13  estimated_value  22216 non-null  float64
#  14  lot_sqft         27607 non-null  float64
#  15  price_per_sqft   0 non-null      float64
# ...
