# %%
from homeharvest import scrape_property
from datetime import datetime, timedelta
import pandas as pd

# %% [markdown]
# ### Example prompt for how to pull data

# %%
# Example for how to pull data
properties = scrape_property(
    location="Logan, UT",
    listing_type="sold", # or (for_sale, for_rent, pending)
    past_days=90, # sold in last 30 days, listed in last 30 days if (for_sale, for_rent)

    # date_from="2023-05-01", alternative to past_days
    # date_to="2023-05-28",
    # foreclosure=True,
    # mls_only=True, # only fetch MLS listings
)

# %%
properties.head()
# Out:
#                                         property_url   mls   mls_id status  \
# 0  https://www.realtor.com/realestateandhomes-det...  SAUT  2004357   SOLD
# 1  https://www.realtor.com/realestateandhomes-det...  SAUT  2006345   SOLD
# 2  https://www.realtor.com/realestateandhomes-det...  SAUT  2001770   SOLD
# 3  https://www.realtor.com/realestateandhomes-det...  SAUT  1996692   SOLD
# 4  https://www.realtor.com/realestateandhomes-det...  SAUT  2002252   SOLD
#
#                                                 text          style  \
# 0  Brimming with potential and waiting for your p...         MOBILE
# 1  Just steps away from Historic Center Street si...  SINGLE_FAMILY
# 2  Charming townhouse in Cache Valley! Minutes fr...      TOWNHOMES
# 3  In the heart of Logan within walking distance ...  SINGLE_FAMILY
# 4  Beautifully maintained home w inviting living ...  SINGLE_FAMILY
#
#       full_street_line       street    unit   city  ... parking_garage  \
# 0          438 S 780 W    438 S 780    <NA>  Logan  ...           <NA>
# 1           29 S 300 W     29 S 300    <NA>  Logan  ...           <NA>
# 2  377 W 1100 N Apt 16   377 W 1100  Apt 16  Logan  ...           <NA>
# 3          530 E 800 N    530 E 800    <NA>  Logan  ...              2
# 4        1918 S 1395 W  1918 S 1395    <NA>  Logan  ...              2
#
#             agent               agent_email  \
# 0  Fox Homes Utah   Leslie@FoxHomesUtah.com
# 1      Anna Sears                      <NA>
# 2      Elvis Ryan                      <NA>
# 3      Curtis Orr  curtisorrhomes@gmail.com
# 4  David Anderson    david@a5realestate.com
#
#                                         agent_phones broker broker_phone  \
# 0  [{'number': '8018723465', 'type': 'Mobile', 'e...   <NA>         <NA>
# 1  [{'number': '8016802662', 'type': 'BUSINESS_MO...   <NA>         <NA>
# 2                                               <NA>   <NA>         <NA>
# 3  [{'number': '4355590698', 'type': 'Mobile', 'e...   <NA>         <NA>
# 4  [{'number': '8014491842', 'type': None, 'ext':...   <NA>         <NA>
#
#   broker_website                                     nearby_schools  \
# 0           <NA>     Logan City District, Bear River Charter School
# 1           <NA>     Logan City District, Bear River Charter School
# 2           <NA>  Intech Collegiate High School, Fast Forward Hi...
# 3           <NA>  Edith Bowen Laboratory School, Intech Collegia...
# 4           <NA>              Cache District, Thomas Edison - North
#
#   primary_photo alt_photos
# 0          <NA>       <NA>
# 1          <NA>       <NA>
# 2          <NA>       <NA>
# 3          <NA>       <NA>
# 4          <NA>       <NA>
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Create a function to pull an entire year of data, month by month to avoid rate limits

# %%
# function to scrape eyarly data
def scrape_yearly_data(year, location, listing_type="sold"):
    # initialize an empty DataFrame to store results
    all_data = pd.DataFrame()

    # iterate through each month of the given year
    for month in range(1, 13):
        # calculate the start and end dates for the month
        date_from = datetime(year, month, 1)
        if month == 12:
            date_to = datetime(year + 1, 1, 1) - timedelta(days=1)
        else:
            date_to = datetime(year, month + 1, 1) - timedelta(days=1)

        # format dates as strings
        date_from_str = date_from.strftime('%Y-%m-%d')
        date_to_str = date_to.strftime('%Y-%m-%d')

        # scrape data for the current month
        monthly_data = scrape_property(
            location=location,
            listing_type=listing_type,
            date_from=date_from_str,
            date_to=date_to_str
        )

        # convert to DataFrame and append to all_data
        monthly_df = pd.DataFrame(monthly_data)
        all_data = pd.concat([all_data, monthly_df], ignore_index=True)
    
    return all_data

# %% [markdown]
# ### Scrape all of Utah's 'Sold' homes from 2023
# - output: any home sold in Utah in 2023
# - if the 'list_date' is later in time than the 'last_sold_date', that means the home was relisted for sale after being sold

# %%
sold_properties_2023 = scrape_yearly_data(2023, "Utah")

# %%
# Check the length of the dataframe to see how many properties were scraped
len(sold_properties_2023)
# Out:
# 30018

# %%
sold_properties_2023.head()
# Out:
#                                         property_url   mls   mls_id status  \
# 0  https://www.realtor.com/realestateandhomes-det...  ICUT   100473   SOLD
# 1  https://www.realtor.com/realestateandhomes-det...  SAUT  1827010   SOLD
# 2  https://www.realtor.com/realestateandhomes-det...  SAUT  1820270   SOLD
# 3  https://www.realtor.com/realestateandhomes-det...  SAUT  1848218   SOLD
# 4  https://www.realtor.com/realestateandhomes-det...  SAUT  1849453   SOLD
#
#                                                 text          style  \
# 0  Enjoy gorgeous mountain views from this beauti...  SINGLE_FAMILY
# 1  PROJECTED COMPLETION DATE OF January 2023. 5-P...      TOWNHOMES
# 2  Utah County's fastest-growing home builder! Ou...      TOWNHOMES
# 3  Come see this charming home now on the market!...  SINGLE_FAMILY
# 4  BACK ON THE MARKET | BUYERS FINANCING FELL THR...  SINGLE_FAMILY
#
#                full_street_line                      street   unit  \
# 0            840 S Peachtree Dr          840 S Peachtree Dr   <NA>
# 1   5502 W Straights Ln S # 151         5502 W Straights Ln  # 151
# 2        809 N Hilltop Dr # 100            809 N Hilltop Dr  # 100
# 3  3822 S Chatterleigh Rd Vly W  3822 S Chatterleigh Rd Vly   <NA>
# 4                 1504 N 1830 W                 1504 N 1830   <NA>
#
#                city  ... parking_garage                   agent  \
# 0       Toquerville  ...              2           The Ames Team
# 1  West Valley City  ...              2  Louise & David Gunther
# 2              Lehi  ...              2              Jamie Lamb
# 3  West Valley City  ...              1       Michelle L Holmes
# 4             Provo  ...              2             Bryan Crown
#
#                   agent_email  \
# 0        Bri@amesteamutah.com
# 1          agunther@remax.net
# 2  jamielamb@bhginfluence.com
# 3                        <NA>
# 4    bryan@mcewenrealtors.com
#
#                                         agent_phones broker broker_phone  \
# 0  [{'number': '435-668-3349', 'type': 'Mobile', ...   <NA>         <NA>
# 1  [{'number': '(801) 518-7000', 'type': 'Home', ...   <NA>         <NA>
# 2  [{'number': '8018775770', 'type': 'Office', 'e...   <NA>         <NA>
# 3  [{'number': '(480) 351-6622', 'type': 'BUSINES...   <NA>         <NA>
# 4  [{'number': '8015201424', 'type': 'Mobile', 'e...   <NA>         <NA>
#
#   broker_website                              nearby_schools  \
# 0           <NA>                         Washington District
# 1           <NA>  Granite District, Ascent Academies Of Utah
# 2           <NA>                                        <NA>
# 3           <NA>  Granite District, Ascent Academies Of Utah
# 4           <NA>             Provo District, Freedom Academy
#
#                                        primary_photo  \
# 0  http://ap.rdcpix.com/697436474f0b38b7b7edc663a...
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#                                           alt_photos
# 0  http://ap.rdcpix.com/697436474f0b38b7b7edc663a...
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
# [5 rows x 43 columns]

# %%
sold_properties_2023['style'].value_counts()
# Out:
# style
# SINGLE_FAMILY                  18770
# TOWNHOMES                       4236
# LAND                            2641
# CONDOS                          1834
# MOBILE                           689
# OTHER                            633
# CONDO                            492
# CONDO_TOWNHOME_ROWHOME_COOP      376
# MULTI_FAMILY                     298
# FARM                               9
# COMMERCIAL                         3
# APARTMENT                          1
# Name: count, dtype: int64

# %% [markdown]
# ### Output unfiltered data to a CSV file for future use

# %%
sold_properties_2023.to_csv('utah_sold_properties_2023.csv')
